# %% [markdown]
# ## Churn Data — Type Description & EDA
#
# ### By:
# jdg
#
# ### Date:
# 2026-02-21
#
# ### Description:
#
# Loads the cleaned primary Parquet file produced by
# `1-data/02_jdg_churn_data_cleaning_20260221.ipynb`.
#
# Goals:
# - Inspect data types and check for remaining `object` columns
# - Detect and quantify missing values (table + heatmap)
# - Explore numeric distributions (histograms, boxplots)
# - Explore categorical and boolean distributions (countplots, bar charts)
# - Analyse the target variable (`Churn`) balance
# - Visualize the tenure vs TotalCharges relationship

# %% [markdown]
# ## 📚 Import libraries

# %%
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
sns.set_theme(style="whitegrid", palette="muted")
plt.rcParams["figure.dpi"] = 100

# %% [markdown]
# ## 💾 Load data

# %%
PRIMARY_PATH = Path("../../data/03_primary/Churn/churn_primary.parquet")

df = pd.read_parquet(PRIMARY_PATH, dtype_backend="numpy_nullable")

print(f"Loaded: {df.shape[0]:,} rows x {df.shape[1]} columns")
df.head()

# %% [markdown]
# ## 👷 Data description

# %% [markdown]
# ### 1. Shape & dtypes

# %%
print(f"Rows   : {df.shape[0]:,}")
print(f"Columns: {df.shape[1]}")
print()
df.info()
# Out:
# Rows   : 7,194
# Columns: 20
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7194 entries, 0 to 7193
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7192 non-null   category
#  1   SeniorCitizen     7159 non-null   boolean
#  2   Partner           7159 non-null   boolean
#  3   Dependents        7131 non-null   boolean
#  4   tenure            7119 non-null   Int16
#  5   PhoneService      7104 non-null   boolean
#  6   MultipleLines     7106 non-null   category
#  7   InternetService   7104 non-null   category
#  8   OnlineSecurity    7071 non-null   category
#  9   OnlineBackup      7066 non-null   category
#  10  DeviceProtection  7069 non-null   category
#  11  TechSupport       7069 non-null   category
#  12  StreamingTV       7067 non-null   category
#  13  StreamingMovies   7083 non-null   category
#  14  Contract          7143 non-null   category
# ...

# %%
dtype_summary = df.dtypes.reset_index().rename(columns={"index": "column", 0: "dtype"})
dtype_summary
# Out:
#               column     dtype
# 0             gender  category
# 1      SeniorCitizen   boolean
# 2            Partner   boolean
# 3         Dependents   boolean
# 4             tenure     Int16
# 5       PhoneService   boolean
# 6      MultipleLines  category
# 7    InternetService  category
# 8     OnlineSecurity  category
# 9       OnlineBackup  category
# 10  DeviceProtection  category
# 11       TechSupport  category
# 12       StreamingTV  category
# 13   StreamingMovies  category
# 14          Contract  category
# 15  PaperlessBilling   boolean
# 16     PaymentMethod  category
# 17    MonthlyCharges   Float64
# 18      TotalCharges   Float64
# 19             Churn   boolean

# %% [markdown]
# ### 2. Missing values

# %%
missing = pd.DataFrame(
    {
        "missing_count": df.isna().sum(),
        "missing_pct": (df.isna().sum() / len(df) * 100).round(2),
    }
)
missing_only = missing[missing["missing_count"] > 0].sort_values("missing_pct", ascending=False)
print(f"Columns with missing values: {len(missing_only)} / {len(df.columns)}")
print(f"Total NaN cells: {df.isna().sum().sum():,}")
print()
missing_only
# Out:
# Columns with missing values: 19 / 20
# Total NaN cells: 1,432
#                   missing_count  missing_pct
# OnlineBackup                128         1.78
# StreamingTV                 127         1.77
# TechSupport                 125         1.74
# DeviceProtection            125         1.74
# OnlineSecurity              123         1.71
# StreamingMovies             111         1.54
# InternetService              90         1.25
# PhoneService                 90         1.25
# MultipleLines                88         1.22
# tenure                       75         1.04
# Dependents                   63         0.88
# PaymentMethod                53         0.74
# PaperlessBilling             52         0.72
# Contract                     51         0.71
# MonthlyCharges               44         0.61
# SeniorCitizen                35         0.49
# Partner                      35         0.49
# TotalCharges                 15         0.21
# ...

# %%
cols_with_na = missing_only.index.tolist()

fig, ax = plt.subplots(figsize=(12, 6))
sns.heatmap(
    df[cols_with_na].isna().astype(int),
    cbar_kws={"label": "Missing (1) / Present (0)"},
    yticklabels=False,
    cmap="YlOrRd",
    ax=ax,
)
ax.set_title("Missing Value Pattern (columns with NaN only)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3. Numeric columns

# %%
df.describe(include=[np.number])
# Out:
#           tenure  MonthlyCharges  TotalCharges
# count     7119.0          7150.0        7179.0
# mean   32.424638       64.804909   2286.181974
# std    24.509287       30.028995   2257.126349
# min          0.0           18.25           0.0
# 25%          9.0           35.75         409.2
# 50%         29.0           70.35        1405.3
# 75%         55.0            89.9        3804.4
# max         72.0          114.85       8045.81

# %%
numeric_cols = ["tenure", "MonthlyCharges", "TotalCharges"]

fig, axes = plt.subplots(len(numeric_cols), 2, figsize=(12, 4 * len(numeric_cols)))

for i, col in enumerate(numeric_cols):
    data = df[col].dropna()
    sns.histplot(data, kde=True, ax=axes[i, 0])
    axes[i, 0].set_title(f"{col} — Distribution")

    sns.boxplot(x=data, ax=axes[i, 1])
    axes[i, 1].set_title(f"{col} — Boxplot")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 4. Categorical columns

# %%
df.describe(include="category")
# Out:
#        gender MultipleLines InternetService OnlineSecurity OnlineBackup  \
# count    7192          7106            7104           7071         7066
# unique      2             3               3              3            3
# top      Male            No     Fiber optic             No           No
# freq     3638          3412            3116           3508         3106
#
#        DeviceProtection TechSupport StreamingTV StreamingMovies  \
# count              7069        7069        7067            7083
# unique                3           3           3               3
# top                  No          No          No              No
# freq               3108        3490        2825            2807
#
#               Contract     PaymentMethod
# count             7143              7141
# unique               3                 4
# top     Month-to-month  Electronic check
# freq              3919              2397

# %%
cat_cols = df.select_dtypes(include="category").columns.tolist()

for col in cat_cols:
    n_unique = df[col].nunique()
    print(f"\n{'─' * 50}")
    print(f"Column : {col}")
    print(f"Ordered: {df[col].cat.ordered}")
    print(f"Unique : {n_unique}")
    print(df[col].value_counts().to_string())
# Out:
# ──────────────────────────────────────────────────
# Column : gender
# Ordered: False
# Unique : 2
# gender
# Male      3638
# Female    3554
#
# ──────────────────────────────────────────────────
# Column : MultipleLines
# Ordered: False
# Unique : 3
# MultipleLines
# No                  3412
# Yes                 3000
# No phone service     694
#
# ──────────────────────────────────────────────────
# Column : InternetService
# Ordered: False
# Unique : 3
# InternetService
# Fiber optic    3116
# DSL            2453
# No             1535
#
# ──────────────────────────────────────────────────
# Column : OnlineSecurity
# Ordered: False
# Unique : 3
# OnlineSecurity
# No                     3508
# Yes                    2035
# No internet service    1528
#
# ──────────────────────────────────────────────────
# Column : OnlineBackup
# Ordered: False
# Unique : 3
# OnlineBackup
# No                     3106
# Yes                    2434
# No internet service    1526
#
# ...

# %%
n_plots = len(cat_cols)
n_grid_cols = 3
n_grid_rows = -(-n_plots // n_grid_cols)

fig, axes = plt.subplots(n_grid_rows, n_grid_cols, figsize=(6 * n_grid_cols, 4.5 * n_grid_rows))
axes = axes.flatten()

for i, col in enumerate(cat_cols):
    order = df[col].value_counts().index
    sns.countplot(data=df, x=col, order=order, ax=axes[i])
    axes[i].set_title(col)
    plt.setp(axes[i].get_xticklabels(), rotation=45, ha="right", fontsize=8)

for j in range(i + 1, len(axes)):
    axes[j].set_visible(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 5. Boolean columns

# %%
bool_cols = df.select_dtypes(include="boolean").columns.drop("Churn").tolist()

for col in bool_cols:
    print(f"\n{'─' * 40}")
    print(f"Column: {col}")
    print(df[col].value_counts(dropna=False).to_string())
# Out:
# ────────────────────────────────────────
# Column: SeniorCitizen
# SeniorCitizen
# False    6001
# True     1158
# <NA>       35
#
# ────────────────────────────────────────
# Column: Partner
# Partner
# False    3698
# True     3461
# <NA>       35
#
# ────────────────────────────────────────
# Column: Dependents
# Dependents
# False    4987
# True     2144
# <NA>       63
#
# ────────────────────────────────────────
# Column: PhoneService
# PhoneService
# True     6410
# False     694
# <NA>       90
#
# ────────────────────────────────────────
# Column: PaperlessBilling
# PaperlessBilling
# True     4232
# False    2910
# <NA>       52

# %%
n_plots = len(bool_cols)
n_grid_cols = 3
n_grid_rows = -(-n_plots // n_grid_cols)

fig, axes = plt.subplots(n_grid_rows, n_grid_cols, figsize=(5 * n_grid_cols, 4 * n_grid_rows))
axes = axes.flatten()

for i, col in enumerate(bool_cols):
    counts = df[col].value_counts(dropna=False)
    labels = [str(x) for x in counts.index]
    ax = axes[i]
    bars = ax.bar(labels, counts.values)
    ax.set_title(col)
    for bar, val in zip(bars, counts.values, strict=False):
        ax.text(
            bar.get_x() + bar.get_width() / 2,
            bar.get_height(),
            f"{val:,}",
            ha="center",
            va="bottom",
            fontsize=9,
        )

for j in range(i + 1, len(axes)):
    axes[j].set_visible(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 6. Target variable — Churn

# %%
churn_counts = df["Churn"].value_counts()
churn_pct = df["Churn"].value_counts(normalize=True).mul(100).round(1)

churn_summary = pd.DataFrame({"count": churn_counts, "pct": churn_pct})
print("Churn distribution:")
print(churn_summary)
print()

fig, ax = plt.subplots(figsize=(6, 4))
labels = ["No Churn (False)", "Churn (True)"]
colors = sns.color_palette("muted", 2)
bars = ax.bar(labels, churn_counts.values, color=colors)

for bar, count, pct in zip(bars, churn_counts.values, churn_pct.values, strict=False):
    ax.text(
        bar.get_x() + bar.get_width() / 2,
        bar.get_height(),
        f"{count:,}\n({pct:.1f}%)",
        ha="center",
        va="bottom",
        fontsize=10,
    )

ax.set_title("Target Variable: Churn Distribution")
ax.set_ylabel("Count")
plt.tight_layout()
plt.show()
# Out:
# Churn distribution:
#        count   pct
# Churn
# False   5285  73.5
# True    1909  26.5

# %% [markdown]
# ### 7. Tenure vs TotalCharges

# %%
scatter_df = df.dropna(subset=["tenure", "TotalCharges", "Churn"]).copy()
scatter_df["Churn_label"] = scatter_df["Churn"].map({True: "Churn", False: "No Churn"})

fig, ax = plt.subplots(figsize=(10, 6))
sns.scatterplot(
    data=scatter_df,
    x="tenure",
    y="TotalCharges",
    hue="Churn_label",
    alpha=0.4,
    s=15,
    ax=ax,
)
ax.set_title("Tenure vs TotalCharges (colored by Churn)")
ax.set_xlabel("Tenure (months)")
ax.set_ylabel("Total Charges ($)")
ax.legend(title="Churn")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 📊 Analysis of Results and Conclusions

# %% [markdown]
# - **Dtypes confirmed**: 6 `boolean`, 11 `category` (1 ordered), 1 `Int16`, 2 `Float64`,
#   0 `object` — all columns carry their semantically correct type
# - **Missing values**: all columns < 2% missing; missing pattern appears random (no
#   systematic block of NaN rows visible in the heatmap) — simple imputation viable
# - **Numeric distributions**: `tenure` is roughly uniform with a spike at 1 month
#   (new customers) and at 72 months (long-term); `MonthlyCharges` is bimodal;
#   `TotalCharges` is right-skewed (most customers have low totals)
# - **Categorical columns**: "No internet service" / "No phone service" values are
#   present — these encode absence of internet/phone rather than missing data and
#   should be consolidated during feature engineering
# - **Class imbalance**: ~26% churn vs ~74% no churn; baseline accuracy is ~74% —
#   imbalance must be addressed in the modelling phase (SMOTE or class weights)
# - **Tenure vs TotalCharges**: strong positive linear relationship (expected); churned
#   customers cluster in the low-tenure, low-total-charges region — short-tenured
#   customers are more likely to churn

# %% [markdown]
# ## 💡 Proposals and Ideas

# %% [markdown]
# - Proceed to `3-analysis/` for correlation analysis and churn breakdown by feature
# - Proceed to `4-feat_eng/` for imputation (all features < 2% missing — median/mode
#   imputation viable) and consolidation of "No internet/phone service" categories
# - Encoding plan: `Contract` (ordinal, already ordered), boolean columns (already binary),
#   remaining categories (one-hot or target encoding)
# - Class imbalance (≈26% vs ≈74%) warrants SMOTE or class-weight adjustment
# - Investigate whether short-tenured customers (tenure < 6 months) drive most churn
